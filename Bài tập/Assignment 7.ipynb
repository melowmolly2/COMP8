# %% [markdown]
# W7A1

# %%
import sys
sys.setrecursionlimit(1000)
a=[i for i in map(int,input().split())]
n=int(input())

def binary_search(arr,left,right,target):
    mid=(left+right)//2
    if left>right:
        return -1
    if(arr[mid]==target):
        return mid
    elif arr[mid]>target:
        return binary_search(arr,left,mid-1,target)
    elif arr[mid]<target:
        return binary_search(arr,mid+1,right,target)

print(binary_search(a,0,len(a)-1,n))
# Out:
# 7

# %% [markdown]
# W7A2

# %%
a=[i for i in map(int,input().split())]
n=int(input())

def count_occurences(arr,x)->int:
    res=0
    for i in arr:
        res+=(x==i)
    return res

print(count_occurences(a,n))
# Out:
# 0

# %% [markdown]
# W7A3

# %% [markdown]
# W7A4

# %% [markdown]
# W7A5

# %%
a=[i for i in map(int,input().split())]
x=int(input())

res=0
for i in range(len(a)-1):
    for j in range(i,len(a)):
        if(a[i]+a[j]==x):
            res+=1

print(res)
# Out:
# 14

# %% [markdown]
# W7A7

# %%
a=[i for i in map(int,input().split())]
dp=[1]*len(a)
for i in range(len(a)):
    for j in range(i):
        if(a[i]>a[j]):
            dp[i]=max(dp[i],dp[j]+1)

res=0

for i in range(len(a)):
    res=max(res,dp[i])

print(res)
# Out:
# 4

# %% [markdown]
# W7A8

# %% [markdown]
# W7A11

# %%
s=input()
word=input()
import re
print(len(re.findall(f"(?={word})",s)))
## ababababa
## aba
## ->3 ???
# Out:
# 4

# %% [markdown]
# W7A10
